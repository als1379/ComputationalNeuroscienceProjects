# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.lines import Line2D
import math

# %%
class LIF():


    def __init__(self, I, Time , time_delta,treshold, u_rest, u_reset, R, tau):
        self.I = I
        self.Time = Time
        self.time_delta = time_delta
        self.u_history = []
        self.fire_time_history = []
        self.u = u_rest
        self.treshold = treshold
        self.u_rest = u_rest
        self.u_reset = u_reset
        self.R = R
        self.tau = tau


    def start(self):
        current_time = 0
        while True:    
            du = (-1 * (self.u - self.u_rest) + self.R * self.I(current_time)/ 1000) / self.tau
            self.u += du * self.time_delta
            if self.u >= self.treshold:
                self.fire_time_history.append(current_time)
                self.u = self.u_reset
            self.u_history.append(self.u)
            current_time += self.time_delta
            if current_time > self.Time:
                break
        return self.u_history


    def show_plot(self):
        plt.plot(range(len(self.u_history)), self.u_history)
        plt.show()

# %%
# constant input

def I(x):
  return 2000

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %%
# sin input 
def I(x):
  return 4000 * (math.sin(x) + 0.9)

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %%
# step input

def I(x):
  if (x // 20) % 2 == 0:
    return 3000
  return 0

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %%
# linear

def I(x):
  return x * 10

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %%
# half negetive linear 
def I(x):
  return 200 * (x - 100)

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %% [markdown]
# random

# %%
import random

def I(x):
  return random.random() * 10000

# %%
lif = LIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
lif.start()
lif.show_plot()

# %% [markdown]
# F-I plot

# %%
ferq = []
for i in range(0, 8000):
  Ii = lambda x: i
  lif = LIF(I=Ii, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001)
  lif.start()
  ferq.append(len(lif.fire_time_history)/lif.Time)
plt.plot(range(len(ferq)), ferq)
plt.show()

# %%
class ELIF():


    def __init__(self, I, Time, time_delta ,treshold, u_rest, u_reset, R, tau, delta_T, theta):
        self.I = I
        self.Time = Time
        self.time_delta = time_delta
        self.u_history = []
        self.fire_time_history = []
        self.u = u_rest
        self.treshold = treshold
        self.u_rest = u_rest
        self.u_reset = u_reset
        self.R = R
        self.tau = tau
        self.delta_T = delta_T
        self.theta = theta



    def start(self):
        current_time = 0
        while True:    
            du = (-1 * (self.u - self.u_rest) + self.delta_T * math.exp((self.u - self.theta)/self.delta_T) + self.R * self.I(current_time)/ 1000) / self.tau
            self.u += du * self.time_delta
            if self.u >= self.treshold:
                self.fire_time_history.append(current_time)
                self.u = self.u_reset
            self.u_history.append(self.u)
            current_time += self.time_delta
            if current_time > self.Time:
                break
        return self.u_history


    def show_plot(self):
        plt.plot(range(len(self.u_history)), self.u_history)
        plt.show()

# %% [markdown]
# u-t plot

# %%
# constant input

def I(x):
  return 4000

# %%
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %%
# sin input 
def I(x):
  return 4000 * (math.sin(x) + 0.9)

# %%
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %%
# step input

def I(x):
  if (x // 20) % 2 == 0:
    return 3000
  return 0

# %%
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %%
# linear

def I(x):
  return x * 10

# %%
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %%
# half negetive linear 
def I(x):
  return 200 * (x - 100)

# %%
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %%
import random

def I(x):
  return random.random() * 10000
Elif = ELIF(I, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=200, time_delta=0.001 ,delta_T=1, theta=-60)
Elif.start()
Elif.show_plot()

# %% [markdown]
# F-I plot

# %%
ferq = []
for i in range(0, 8000):
  Ii = lambda x: i
  Elif =  ELIF(Ii, treshold=-55, u_rest=-70, u_reset=-65, R=14, tau=28, Time=100, time_delta=0.001, delta_T=1, theta=-60)
  Elif.start()
  ferq.append(len(Elif.fire_time_history)/Elif.Time)
plt.plot(range(len(ferq)), ferq)
plt.show()

# %% [markdown]
# Adaptive ELIF

# %%
class AELIF():


    def __init__(self, I, Time, time_delta,treshold, u_rest, u_reset, R, tau, delta_T, theta, a, b, tau_w):
        self.I = I
        self.Time = Time
        self.time_delta = time_delta
        self.u_history = []
        self.w_history = []
        self.fire_time_history = []
        self.u = u_rest
        self.treshold = treshold
        self.u_rest = u_rest
        self.u_reset = u_reset
        self.R = R
        self.tau = tau
        self.delta_T = delta_T
        self.theta = theta
        self.a = a
        self.b = b
        self.tau_w = tau_w
        self.w = 0



    def start(self):
        current_time = 0
        while True:    
            dw = ((self.a * (self.u - self.u_rest)) - self.w) / self.tau_w + self.b * len(self.fire_time_history)
            self.w += dw * self.time_delta
            du = (-1 * (self.u - self.u_rest) + self.delta_T * math.exp((self.u - self.theta)/self.delta_T) - self.R * self.w / 1000 + self.R * self.I(current_time)/ 1000) / self.tau
            self.u += du * self.time_delta
            if self.u >= self.treshold:
                self.u = self.u_reset
                self.fire_time_history.append(current_time)
            self.u_history.append(self.u)
            self.w_history.append(self.w)
            current_time += self.time_delta
            if current_time > self.Time:
                break
        return self.u_history


    def show_plot_ut(self):
        plt.plot(range(len(self.u_history)), self.u_history)
        plt.show()

    def show_plot_wt(self):
        plt.plot(range(len(self.w_history)), self.w_history)
        plt.show()

# %%
# constant input

def I(x):
  return 2000

# %%
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
# sin input 
def I(x):
  return 4000 * (math.sin(x) + 0.9)

# %%
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
# step input

def I(x):
  if (x // 20) % 2 == 0:
    return 3000
  return 0

# %%
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
# linear

def I(x):
  return x * 10

# %%
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
# half negetive linear 
def I(x):
  return 200 * (x - 100)

# %%
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
import random

def I(x):
  return random.random() * 10000
aelif = AELIF(I=I, treshold=-50, u_rest=-70, u_reset=-65, R=10, tau=8, Time=100, time_delta=0.1, 
    delta_T=1, theta=-60,
     a=0.01, b=100, tau_w=1)
aelif.start()
aelif.show_plot_ut()

# %%
aelif.show_plot_wt()
